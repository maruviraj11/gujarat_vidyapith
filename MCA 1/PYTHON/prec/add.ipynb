# %%
num=int(input("enter a any number:"));
num1=int(input("enter a any number:"));

sum=num+num1;

print("sum of the number:",sum);
# Out:
# enter a any number: 10
# enter a any number: 20
# sum of the number: 30
